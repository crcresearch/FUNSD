# %% [markdown]
# # Show Azure Annotations

# %%
import sys
sys.path.append('..')
from src.utils import plot_azure_annotations

# Paths to the image and annotations files
image_path = './data/83635935.png'
annotations_path = './data/83635935_azure.json'
annotations_path = './data/83635935_prebuilt-read.json'

# Plot the annotations
plot_azure_annotations(image_path, annotations_path)
